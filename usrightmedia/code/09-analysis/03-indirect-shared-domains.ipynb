# %% [markdown]
# ## Indirectly Shared Domains
#
# **Purpose**: detect indirect resonance by checking if (re-)tweeted URLs are in the "follower" position of news event dyads (see `09-analysis/01-newsevents-dyadic-comparison.ipynb` for details).
# - Case A: If a (re-)tweeted URL is in the first position of a dyad, it is in the "lead" position and does not count as indirect resonance.
# - Case B: If a (re-)tweeted URL is in the second position of a dyad, it is in the "follower" position and does count as indirect resonance.
#     - e.g., If a politician directly (re-)tweets a URL from Fox News, but the first outlet to cover the news event is actually Breitbart.
#
# **Steps**:
# 1. Load files
#     - 1.1 load directly (re-)tweeted domains -> filter out unmatcheable URLs
#         - contains columns which are useful for filtering (established right/alternative right, topic, etc.)
#     - 1.2 load (re-)tweeted URLs which are linked to news event dyads
#         - for detecting indirect resonance
# 2. Find which (re-)tweeted URLs are matched to multi-article news events
#     - 2.1:
#         - process the dyads so that each "follower" (`d1`) article also has information about the "lead" (`d0`) article
#         - create dataframe where each row is a (re-)tweeted URL which is part of a multi-article news event
#     - 2.2: merge the (re-)tweeted URL dataframe with the dyadic URLs dataframe
#     - 2.3: split dataframes into two versions based on whether the (re-)tweeted URL is associated with an article in a "lead" (`d0`) of "follower" (`d1`) position
# 3. Plot "follower" URLs

# %%
import os
import pickle
import pandas as pd

# %matplotlib inline
import plotnine as p9
from mizani.breaks import date_breaks
from mizani.formatters import date_format, percent_format

# %%
from usrightmedia.shared.clusters_utils import extract_dyads
# Out:
# WARNING:INCA:$DISPLAY environment variable is not set, trying a different approach. You probably are running INCA on a text console, right?
# WARNING:INCA:$DISPLAY environment variable is not set, trying a different approach. You probably are running INCA on a text console, right?
# INFO:INCA:Providing verbose output

# %%
dyads_dir = os.path.join("..", "..", "data", "02-intermediate", "07-newsevents", "06-softcosine-dyads")
urls_dir = os.path.join("..", "..", "data", "03-analysis")
figs_dir = os.path.join("..", "..", "figures", "indirect")

def save_image(obj, name, height=5.5, width=5.5, units="in", dpi=600):
    obj.save(filename = os.path.join(figs_dir, "png", f'{name}.png'), height=height, width=width, units=units, dpi=dpi)

threshold = "softcos06"

# %% [markdown]
# ### 1. Load files

# %% [markdown]
# #### 1.1 Directly shared URLs

# %%
df_direct_urls = pd.read_pickle(os.path.join(urls_dir, "direct_shared_domains.pkl"))

# %% [markdown]
# - before filtering

# %%
print(f"{len(df_direct_urls)} (re-)tweeted URLs (unfiltered).")
df_direct_urls.groupby('standardized_url').size().sort_values(ascending=False).head(20)
# Out:
# 36019 (re-)tweeted URLs (unfiltered).
# standardized_url
# www.washingtonpost.com/__connectionpool_error__                                                      1692
# www.washingtonexaminer.com/tag/donald-trump                                                           626
# www.washingtonexaminer.com/tag/barack-obama                                                           173
# www.newsmax.com/__connectionpool_error__                                                              142
# www.washingtonexaminer.com/tag/hillary-clinton                                                        132
# go.com/__client_error__                                                                               123
# www.washingtonexaminer.com/tag/supreme-court                                                          101
# foxnews.com/__client_error__                                                                           72
# washingtonpost.com/__client_error__                                                                    62
# washingtonexaminer.com/__client_error__                                                                56
# nytimes.com/__client_error__                                                                           50
# www.washingtonexaminer.com/tag/nancy-pelosi                                                            42
# www.snappytv.com/__connectionpool_error__                                                              35
# www.wsj.com/articles/u-s-is-worlds-most-competitive-economy-for-first-time-in-a-decade-1539727213      34
# www.washingtonexaminer.com/policy/economy/hires-rise-to-highest-level-in-17-years                      33
# www.politico.com/news/2019/12/07/mark-esper-pensacola-shooting-077741                                  30
# www.washingtonexaminer.com/va-secretary-disney-doesnt-measure-wait-times-so-why-should-va              30
# wsj.com/__client_error__                                                                               25
# www.foxnews.com/politics/planned-parenthood-coronavirus-stimulus-money-ppp-return                      24
# www.cbsnews.com/__connectionpool_error__                                                               23
# dtype: int64

# %% [markdown]
# - after filtering

# %%
df_direct_urls = df_direct_urls.loc[(df_direct_urls['is_selected_outlet'])].reset_index(drop=True)
print(f"{len(df_direct_urls)} (re-)tweeted URLs. Filtered for selected outlets.")
# Out:
# 13961 (re-)tweeted URLs. Filtered for selected outlets.

# %%
df_direct_urls = df_direct_urls.loc[(df_direct_urls['urlexpander_error']=="no error")].reset_index(drop=True)
print(f"{len(df_direct_urls)} (re-)tweeted URLs. Filtered for selected outlets and no urlExpander error.")
# Out:
# 13645 (re-)tweeted URLs. Filtered for selected outlets and no urlExpander error.

# %%
df_direct_urls = df_direct_urls.loc[~(df_direct_urls['standardized_url'].str.contains('www.washingtonexaminer.com/tag'))        
                                    & ~(df_direct_urls['standardized_url'].str.contains('www.foxnews.com/category'))
                                    & ~(df_direct_urls['standardized_url'].str.contains('radio.foxnews.com/fox-news-talk'))
                                    & ~(df_direct_urls['standardized_url'].str.contains('radio.foxnews.com/podcast'))
                                    & ~(df_direct_urls['standardized_url'].str.contains('video.fox'))].reset_index(drop=True)
print(f"{len(df_direct_urls)} (re-)tweeted URLs. Filtered for selected outlets, no urlExpander error, and no generic URLs.")
df_direct_urls.groupby('standardized_url').size().sort_values(ascending=False).head(20)
# Out:
# 11231 (re-)tweeted URLs. Filtered for selected outlets, no urlExpander error, and no generic URLs.
# standardized_url
# www.washingtonexaminer.com/policy/economy/hires-rise-to-highest-level-in-17-years                                         33
# www.washingtonexaminer.com/va-secretary-disney-doesnt-measure-wait-times-so-why-should-va                                 30
# www.foxnews.com/politics/planned-parenthood-coronavirus-stimulus-money-ppp-return                                         24
# www.foxbusiness.com/economy/us-wage-growth-hits-17-month-high                                                             20
# radio.foxnews.com/player-files/radio.php                                                                                  19
# www.washingtonexaminer.com/washington-secrets/record-high-business-optimism-need-for-employees-at-45-year-high            17
# www.foxbusiness.com/economy/ppp-51-million-jobs-coronavirus-house-republicans                                             16
# www.washingtonexaminer.com/over-100-companies-giving-trump-bonuses-after-tax-victory-tsunami-building                     16
# www.foxnews.com/politics/scotus-upholds-religious-exemptions-to-obamacare-contraception-coverage                          15
# www.foxbusiness.com/markets/american-money-is-flowing-back-into-america                                                   14
# www.foxbusiness.com/economy/january-jobs-report-released-by-department-of-labor                                           13
# www.foxbusiness.com/economy/small-business-optimism-at-35-year-high                                                       13
# www.foxnews.com/politics/pelosi-san-francisco-hair-salon-owner-calls-it-slap-in-the-face                                  12
# www.foxnews.com/opinion/sen-cotton-our-president-desperately-needs-an-obamacare-reality-check                             12
# www.foxbusiness.com/economy/august-jobs-report-coronavirus-pandemic-2020                                                  11
# www.foxbusiness.com/economy/us-regains-title-of-worlds-most-competitive-economy                                           11
# www.foxnews.com/politics/bipartisan-house-resolution-condemns-chinese-government-over-handling-of-coronavirus-response    11
# www.foxbusiness.com/economy/may-2020-jobs-report                                                                          11
# www.washingtonexaminer.com/opinion/op-eds/the-fauci-birx-doctrine-of-destruction                                          11
# www.foxnews.com/politics/nancy-pelosi-refuses-to-denounce-socialism                                                       10
# dtype: int64

# %% [markdown]
# #### 1.2 Load URLs which are associated with news event dyads

# %%
with open(os.path.join(dyads_dir, f'{threshold}_dyads_cx_filtered_IPR.pkl'), 'rb') as file:
      dyads_cx_filtered_IPR = pickle.load(file)
    
dyads_filtered_IPR = extract_dyads(dyads_cx_filtered_IPR)

# %%
print(f"{len(dyads_filtered_IPR)} dyads between different doctypes.")
# Out:
# 98692 dyads between different doctypes.

# %% [markdown]
# - As shown in the example below, each item in a dyad has a `doc_tw` key which lists whether the particular article was directly (re-)tweeted 1+ times.
# - We can then use the dyads to figure out if the outlet associated with the directly (re-)tweeted URL was the "leader" in covering this news event or if it was a "follower".

# %%
# example
# note: cluster size is based on original cluster size
# It will not necessary match with the count of dyads in dyads_filtered_IPR because dyads_filtered_IPR is filtered to `keep_dyads_bn_diff_doctypes_only=True`
dyads_cx_filtered_IPR["softcos06_9916"]
# Out:
# [({'cluster_id': 'softcos06_9916',
#    'cluster_size': 4,
#    'doc_id': 'FoxNews_1439280633',
#    'doc_publish_date': Timestamp('2019-11-07 17:21:04+0000', tz='UTC'),
#    'doc_title': "Donald Trump Jr. blasts 'The View' hosts for Joy Behar's 'blackface' and Whoopi Goldberg comments on Polanski",
#    'doctype': 'foxnews',
#    'doctype_ideo': 'est',
#    'doc_topic': 'topic3',
#    'doc_tw': ['jasoninthehouse_1192526992236630016_0']},
#   {'cluster_id': 'softcos06_9916',
#    'cluster_size': 4,
#    'doc_id': 'InfoWars_1439434418',
#    'doc_publish_date': Timestamp('2019-11-07 19:25:10+0000', tz='UTC'),
#    'doc_title': 'Don Jr. Absolutely Destroys Liberal Hosts of ABC&#8217;s The View',
#    'doctype': 'infowars',
#    'doctype_ideo': 'alt',
#    'doc_topic': 'topic2',
#    'doc_tw': []}),
#  ({'cluster_id': 'softcos06_9916',
#    'cluster_size': 4,
#    'doc_id': 'FoxNews_1439280633',
#    'doc_publish_date': Timestamp('2019-11-07 17:21:04+0000', tz='UTC'),
#    'doc_title': "Donald Trump Jr. blasts 'The View' hosts for Joy Behar's 'blackface' and Whoopi Goldberg comments on Polanski",
#    'doctype': 'foxnews',
#    'doctype_ideo': 'est',
#    'doc_topic': 'topic3',
#    'doc_tw': ['jasoninthehouse_1192526992236630016_0']},
#   {'cluster_id': 'softcos06_9916',
#    'cluster_size': 4,
#    'doc_id': 'Breitbart_1439616912',
#    'doc_publish_date': Timestamp('2019-11-07 21:43:22+0000', tz='UTC'),
#    'doc_title': "Fact Check: Joy Behar Denies Wearing Blackface Despite Dressing Up as 'Beautiful African Woman'",
#    'doctype': 'breitbart',
#    'doctype_ideo': 'alt',
#    'doc_topic': 'topic2',
#    'doc_tw': []})]

# %% [markdown]
# ### 2. Find which (re-)tweeted URLs are matched to multi-article news events
# - `softcos06`: `There are 518233 single-article clusters and 62887 multiple-article clusters.`

# %% [markdown]
# #### 2.1 Set up dataframe where each row is a (re-)tweeted URL which is part of a multi-article news event

# %%
tweeted_docs = []
for dyad in dyads_filtered_IPR:
    for n, item in enumerate(dyad):
        if len(item["doc_tw"]) > 0: # keep articles which were (re-)tweeted 1+ times by a politician
            item["d0_doc_id"] = dyad[0]["doc_id"] # for all articles ("lead" or "follower"), augment with the initiating article's doc_id
            item["d0_doctype"] = dyad[0]["doctype"] # ... augment with the initiating article's doctype
            if n == 0:
                # lead
                item["dyad_pos"] = 0
                item["d1_doc_id"] = None # this is a "lead" article so "follower" (d1) is None
                item["d1_doctype"] = None
            elif n == 1:
                # follower
                item["dyad_pos"] = 1
                item["d1_doc_id"] = item["doc_id"]
                item["d1_doctype"] = item["doctype"]
            tweeted_docs.append(item)
            
# drop_duplicates: The first item (document) within each dyad is identical to the other dyads within the same cluster. Keep the first instance only.
# explode: The doc_tw column contains a list of tweets2_url IDs. 'Explode' the dataframe so that each row corresponds with a (re-)tweeted URL. The values of the other columns are duplicated.
df_dyadic_urls = pd.DataFrame(tweeted_docs)\
               .drop_duplicates(subset=["cluster_id","doc_id"], keep="first")\
               .explode("doc_tw")\
               .reset_index(drop=True)\
               .rename(columns={"doc_tw": "url_id"})
print(f"{len(df_dyadic_urls)} (re-)tweeted URLs are part of multi-article news events.")
df_dyadic_urls
# Out:
# 2162 (re-)tweeted URLs are part of multi-article news events.
#            cluster_id  cluster_size                        doc_id  \
# 0       softcos06_100            44        DailyCaller_1593668519
# 1      softcos06_1000            16        DailyCaller_1637449942
# 2     softcos06_10048             4            FoxNews_1790875424
# 3     softcos06_10048             4            FoxNews_1790875424
# 4     softcos06_10048             4            FoxNews_1790875424
# ...               ...           ...                           ...
# 2157    softcos06_991            16  WashingtonExaminer_470106918
# 2158    softcos06_991            16  WashingtonExaminer_470530063
# 2159   softcos06_9916             4            FoxNews_1439280633
# 2160   softcos06_9920             4             FoxNews_738376893
# 2161   softcos06_9966             4            FoxNews_1656632357
#
#               doc_publish_date  \
# 0    2020-04-30 19:50:59+00:00
# 1    2020-06-17 16:03:18+00:00
# 2    2020-12-07 19:36:08+00:00
# 3    2020-12-07 19:36:08+00:00
# 4    2020-12-07 19:36:08+00:00
# ...                        ...
# 2157 2016-05-24 15:14:46+00:00
# 2158 2016-05-25 15:32:56+00:00
# 2159 2019-11-07 17:21:04+00:00
# 2160 2017-12-06 21:45:00+00:00
# 2161 2020-07-08 23:37:21+00:00
#
#                                               doc_title             doctype  \
# 0     FBI Planned To Close Michael Flynn Investigati...         dailycaller
# 1     Hawley Announces Bill Targeting Bad-Acting Tec...         dailycaller
# 2     GOP Rep. Ken Buck calls for Hunter Biden speci...             foxnews
# 3     GOP Rep. Ken Buck calls for Hunter Biden speci...             foxnews
# 4     GOP Rep. Ken Buck calls for Hunter Biden speci...             foxnews
# ...                                                 ...                 ...
# 2157             Ryan: VA chief's comments 'disgusting'  washingtonexaminer
# 2158          Cruz calls for VA's McDonald to step down  washingtonexaminer
# 2159  Donald Trump Jr. blasts 'The View' hosts for J...             foxnews
# 2160  House passes gun reciprocity, faces challenge ...             foxnews
# 2161  Biden's Dem platform recommendations signal co...             foxnews
#
#      doctype_ideo doc_topic                                 url_id  \
# 0             est    topic2         RepGosar_1255970074151837698_0
# 1             est    topic2   SenHawleyPress_1280877113118261249_0
# 2             est    topic3       RepKenBuck_1336495790735454209_0
# 3             est    topic3       RepKenBuck_1336049448317841424_0
# 4             est    topic3       Jim_Jordan_1336496476067942400_0
# ...           ...       ...                                    ...
# 2157          est    topic1       SpeakerRyan_735213887226806272_0
# 2158          est    topic1        SenTedCruz_735497975728836609_0
# 2159          est    topic3  jasoninthehouse_1192526992236630016_0
# 2160          est    topic1     RepRichHudson_938560036858671104_0
# 2161          est    topic3       SenTedCruz_1281620426570039298_0
#
#                          d0_doc_id          d0_doctype  dyad_pos  \
# 0               FoxNews_1590605950             foxnews         1
# 1               FoxNews_1652437807             foxnews         1
# 2               FoxNews_1790875424             foxnews         0
# 3               FoxNews_1790875424             foxnews         0
# 4               FoxNews_1790875424             foxnews         0
# ...                            ...                 ...       ...
# 2157             FoxNews_469768825             foxnews         1
# 2158             FoxNews_469768825             foxnews         1
# 2159            FoxNews_1439280633             foxnews         0
# 2160  WashingtonExaminer_737721767  washingtonexaminer         1
# 2161            FoxNews_1656632357             foxnews         0
#
#                          d1_doc_id          d1_doctype
# 0           DailyCaller_1593668519         dailycaller
# 1           DailyCaller_1637449942         dailycaller
# 2                             None                None
# 3                             None                None
# 4                             None                None
# ...                            ...                 ...
# 2157  WashingtonExaminer_470106918  washingtonexaminer
# 2158  WashingtonExaminer_470530063  washingtonexaminer
# 2159                          None                None
# 2160             FoxNews_738376893             foxnews
# 2161                          None                None
#
# [2162 rows x 14 columns]

# %%
# identifiable (re-)tweeted URLs: is_selected_outlet==True, not a urlExpander error, and not a generic URL
# identifiable multi-article news events: clusters based on softcos06 threshold (may not be comprehensive of all actual news events; tradeoff where higher softcos* means fewer false positives + lower recall)
print(f"{round(len(df_dyadic_urls)/len(df_direct_urls),2)*100}% of identifiable (re-)tweeted URLs are part of identifiable multi-article news events.")
# Out:
# 19.0% of identifiable (re-)tweeted URLs are part of identifiable multi-article news events.

# %%
print(f"{df_dyadic_urls['cluster_id'].nunique()} distinct news events were (re-)tweeted.")
# Out:
# 1356 distinct news events were (re-)tweeted.

# %%
# number of (re-)tweets associated with each news event (i.e., cluster_id)
df_dyadic_urls.groupby("cluster_id").size().sort_values(ascending=False)
# Out:
# cluster_id
# softcos06_1011     16
# softcos06_92       12
# softcos06_393      11
# softcos06_15       11
# softcos06_48181    10
#                    ..
# softcos06_27214     1
# softcos06_27242     1
# softcos06_27335     1
# softcos06_27426     1
# softcos06_9966      1
# Length: 1356, dtype: int64

# %%
# number of (re-)tweets associated with each outlet
df_dyadic_urls.groupby("doctype").size()
# Out:
# doctype
# breitbart              155
# dailycaller            208
# foxnews               1640
# gatewaypundit            4
# seanhannity              4
# washingtonexaminer     151
# dtype: int64

# %%
df_dyadic_urls.loc[df_dyadic_urls["cluster_id"]=="softcos06_1011"]
# Out:
#         cluster_id  cluster_size                  doc_id  \
# 17  softcos06_1011            16      FoxNews_1656249880
# 18  softcos06_1011            16      FoxNews_1656249880
# 19  softcos06_1011            16      FoxNews_1656249880
# 20  softcos06_1011            16      FoxNews_1656249880
# 21  softcos06_1011            16      FoxNews_1656249880
# 22  softcos06_1011            16      FoxNews_1656249880
# 23  softcos06_1011            16      FoxNews_1656249880
# 24  softcos06_1011            16      FoxNews_1656249880
# 25  softcos06_1011            16      FoxNews_1656249880
# 26  softcos06_1011            16      FoxNews_1656249880
# 27  softcos06_1011            16      FoxNews_1656249880
# 28  softcos06_1011            16      FoxNews_1656249880
# 29  softcos06_1011            16      FoxNews_1656249880
# 30  softcos06_1011            16      FoxNews_1656249880
# 31  softcos06_1011            16      FoxNews_1656249880
# 32  softcos06_1011            16  DailyCaller_1657596410
#
#             doc_publish_date  \
# 17 2020-07-08 14:19:10+00:00
# 18 2020-07-08 14:19:10+00:00
# 19 2020-07-08 14:19:10+00:00
# 20 2020-07-08 14:19:10+00:00
# 21 2020-07-08 14:19:10+00:00
# 22 2020-07-08 14:19:10+00:00
# 23 2020-07-08 14:19:10+00:00
# 24 2020-07-08 14:19:10+00:00
# 25 2020-07-08 14:19:10+00:00
# 26 2020-07-08 14:19:10+00:00
# 27 2020-07-08 14:19:10+00:00
# 28 2020-07-08 14:19:10+00:00
# 29 2020-07-08 14:19:10+00:00
# 30 2020-07-08 14:19:10+00:00
# 31 2020-07-08 14:19:10+00:00
# 32 2020-07-09 20:26:52+00:00
#
#                                             doc_title      doctype  \
# 17  Supreme Court rules in favor of Little Sisters...      foxnews
# 18  Supreme Court rules in favor of Little Sisters...      foxnews
# 19  Supreme Court rules in favor of Little Sisters...      foxnews
# 20  Supreme Court rules in favor of Little Sisters...      foxnews
# 21  Supreme Court rules in favor of Little Sisters...      foxnews
# 22  Supreme Court rules in favor of Little Sisters...      foxnews
# 23  Supreme Court rules in favor of Little Sisters...      foxnews
# 24  Supreme Court rules in favor of Little Sisters...      foxnews
# 25  Supreme Court rules in favor of Little Sisters...      foxnews
# 26  Supreme Court rules in favor of Little Sisters...      foxnews
# 27  Supreme Court rules in favor of Little Sisters...      foxnews
# 28  Supreme Court rules in favor of Little Sisters...      foxnews
# 29  Supreme Court rules in favor of Little Sisters...      foxnews
# 30  Supreme Court rules in favor of Little Sisters...      foxnews
# 31  Supreme Court rules in favor of Little Sisters...      foxnews
# 32  REP. JODY HICE: Victory At Last For The Little...  dailycaller
#
#    doctype_ideo doc_topic                                 url_id  \
# 17          est    topic2     RepRickAllen_1280909146498482176_0
# 18          est    topic2    CongHuelskamp_1280893313332150273_0
# 19          est    topic2   RepDougCollins_1280898918486888448_0
# 20          est    topic2    RepMarkWalker_1280915664249774080_0
# 21          est    topic2    RepJasonSmith_1280984378340978688_0
# 22          est    topic2      RepRonEstes_1280978404632903685_0
# 23          est    topic2     virginiafoxx_1280902040835760129_0
# 24          est    topic2     RepMarkGreen_1280941009929633793_0
# 25          est    topic2  AustinScottGA08_1281017493260247041_0
# 26          est    topic2        RepDLesko_1280915947352731650_0
# 27          est    topic2      RepWalorski_1280978340510384129_0
# 28          est    topic2     SenJoniErnst_1281028487298629633_0
# 29          est    topic2  CongressmanHice_1280878624611217408_0
# 30          est    topic2      RepJimBanks_1280894532712882177_0
# 31          est    topic2      RepTomEmmer_1281254311834648576_0
# 32          est    topic1  CongressmanHice_1281330303693447171_0
#
#              d0_doc_id d0_doctype  dyad_pos               d1_doc_id  \
# 17  FoxNews_1656249880    foxnews         0                    None
# 18  FoxNews_1656249880    foxnews         0                    None
# 19  FoxNews_1656249880    foxnews         0                    None
# 20  FoxNews_1656249880    foxnews         0                    None
# 21  FoxNews_1656249880    foxnews         0                    None
# 22  FoxNews_1656249880    foxnews         0                    None
# 23  FoxNews_1656249880    foxnews         0                    None
# 24  FoxNews_1656249880    foxnews         0                    None
# 25  FoxNews_1656249880    foxnews         0                    None
# 26  FoxNews_1656249880    foxnews         0                    None
# 27  FoxNews_1656249880    foxnews         0                    None
# 28  FoxNews_1656249880    foxnews         0                    None
# 29  FoxNews_1656249880    foxnews         0                    None
# 30  FoxNews_1656249880    foxnews         0                    None
# 31  FoxNews_1656249880    foxnews         0                    None
# 32  FoxNews_1656249880    foxnews         1  DailyCaller_1657596410
#
#      d1_doctype
# 17         None
# 18         None
# 19         None
# 20         None
# 21         None
# 22         None
# 23         None
# 24         None
# 25         None
# 26         None
# 27         None
# 28         None
# 29         None
# 30         None
# 31         None
# 32  dailycaller

# %% [markdown]
# #### 2.2 merge the (re-)tweeted URL dataframe with the dyadic URLs dataframe

# %%
df_direct_urls['url_id'] = df_direct_urls['username'] + '_' + df_direct_urls['url_id']
df_direct_urls.head()
# Out:
#                                   url_id          created_at created_at_year  \
# 0       KenCalvert_1016809976789159937_0 2018-07-10 22:22:44      2018-01-01
# 1        KenCalvert_706936239220330498_0 2016-03-07 20:15:08      2016-01-01
# 2       RepComstock_735190770035138560_0 2016-05-24 19:28:33      2016-01-01
# 3          RepByrne_971799132707926016_0 2018-03-08 17:25:43      2018-01-01
# 4  RepChrisStewart_1204042988285919233_0 2019-12-09 14:19:53      2019-01-01
#
#           username                                   standardized_url  \
# 0       KenCalvert  www.washingtonexaminer.com/policy/economy/hire...
# 1       KenCalvert  www.washingtonexaminer.com/how-a-new-bill-to-f...
# 2      RepComstock  www.washingtonexaminer.com/lawmaker-let-privat...
# 3         RepByrne  www.washingtonexaminer.com/how-to-end-governme...
# 4  RepChrisStewart  www.washingtonexaminer.com/opinion/utah-republ...
#
#                url_netloc urlexpander_error               outlet  \
# 0  washingtonexaminer.com          no error  Washington Examiner
# 1  washingtonexaminer.com          no error  Washington Examiner
# 2  washingtonexaminer.com          no error  Washington Examiner
# 3  washingtonexaminer.com          no error  Washington Examiner
# 4  washingtonexaminer.com          no error  Washington Examiner
#
#            outlet_std  is_selected_outlet  pew_libdem  pew_consrep  \
# 0  washingtonexaminer                True        14.0         44.0
# 1  washingtonexaminer                True        14.0         44.0
# 2  washingtonexaminer                True        14.0         44.0
# 3  washingtonexaminer                True        14.0         44.0
# 4  washingtonexaminer                True        14.0         44.0
#
#    pew_libdem_consrep_diff ideo_category   ideo_subcategory  ideo_left2right
# 0                    -29.0         right  established right             24.0
# 1                    -29.0         right  established right             24.0
# 2                    -29.0         right  established right             24.0
# 3                    -29.0         right  established right             24.0
# 4                    -29.0         right  established right             24.0

# %%
df_urls = df_direct_urls.merge(right=df_dyadic_urls, how="left", on="url_id")

# %% [markdown]
# #### 2.3 filtered versions for (re-)tweets which are in "lead" position (`dyad_pos==0`) vs. "follower" position (`dyad_pos==1`)

# %%
df_urls_d0 = df_urls.loc[df_urls['dyad_pos']==0].reset_index(drop=True)
df_urls_d1 = df_urls.loc[df_urls['dyad_pos']==1].reset_index(drop=True)
# not exporting at this point

# %%
with pd.option_context("display.max_colwidth", None):
    display(df_urls_d0)
# Out:
#                                     url_id          created_at  \
# 0          Jim_Jordan_847827446670000128_0 2017-03-31 15:06:29
# 1        SenTomCotton_709496134062964737_0 2016-03-14 21:47:14
# 2     replouiegohmert_786944004416008192_0 2016-10-14 14:57:26
# 3          JohnCornyn_888845201011298305_0 2017-07-22 19:36:24
# 4        RepTomGraves_862679831779172352_0 2017-05-11 14:44:34
# ..                                     ...                 ...
# 888    RepGregSteube_1280230036088463360_0 2020-07-06 20:00:00
# 889    RepFrenchHill_1176931491575676929_0 2019-09-25 18:48:28
# 890  RepThomasMassie_1248777133285158912_0 2020-04-11 00:57:24
# 891  RepThomasMassie_1249816195315965960_0 2020-04-13 21:46:16
# 892         RandPaul_1248774960992137217_0 2020-04-11 00:48:46
#
#     created_at_year         username  \
# 0        2017-01-01       Jim_Jordan
# 1        2016-01-01     SenTomCotton
# 2        2016-01-01  replouiegohmert
# 3        2017-01-01       JohnCornyn
# 4        2017-01-01     RepTomGraves
# ..              ...              ...
# 888      2020-01-01    RepGregSteube
# 889      2019-01-01    RepFrenchHill
# 890      2020-01-01  RepThomasMassie
# 891      2020-01-01  RepThomasMassie
# 892      2020-01-01         RandPaul
#
#                                                                                                              standardized_url  \
# 0                                            www.washingtonexaminer.com/freedom-caucuss-reasonable-demand-on-obamacare-repeal
# 1                  www.washingtonexaminer.com/ice-124-illegal-immigrants-released-from-jail-later-charged-in-138-murder-cases
# 2                              www.washingtonexaminer.com/sw-border-crisis-95-of-illegals-drugs-get-in-from-mexico-undetected
# 3                                www.washingtonexaminer.com/john-mccains-daughter-meghan-tweets-picture-amazing-hike-with-dad
# 4                                  www.washingtonexaminer.com/aetna-completely-exits-obamacare-exchanges-cites-massive-losses
# ..                                                                                                                        ...
# 888                                                             www.foxbusiness.com/economy/june-jobs-report-2020-coronavirus
# 889                                                                 www.foxbusiness.com/politics/us-japan-trade-deal-on-track
# 890  www.thegatewaypundit.com/2020/04/kentucky-record-license-plates-churchgoers-easter-weekend-force-self-quarantine-14-days
# 891                             www.thegatewaypundit.com/2020/04/gop-rep-massie-warns-us-weeks-away-not-months-food-shortages
# 892  www.thegatewaypundit.com/2020/04/kentucky-record-license-plates-churchgoers-easter-weekend-force-self-quarantine-14-days
#
#                  url_netloc urlexpander_error               outlet  \
# 0    washingtonexaminer.com          no error  Washington Examiner
# 1    washingtonexaminer.com          no error  Washington Examiner
# 2    washingtonexaminer.com          no error  Washington Examiner
# 3    washingtonexaminer.com          no error  Washington Examiner
# 4    washingtonexaminer.com          no error  Washington Examiner
# ..                      ...               ...                  ...
# 888         foxbusiness.com          no error             Fox News
# 889         foxbusiness.com          no error             Fox News
# 890    thegatewaypundit.com          no error   The Gateway Pundit
# 891    thegatewaypundit.com          no error   The Gateway Pundit
# 892    thegatewaypundit.com          no error   The Gateway Pundit
#
#              outlet_std  is_selected_outlet  ...          doc_publish_date  \
# 0    washingtonexaminer                True  ... 2017-03-31 04:00:00+00:00
# 1    washingtonexaminer                True  ... 2016-03-14 04:00:00+00:00
# 2    washingtonexaminer                True  ... 2016-10-13 04:00:00+00:00
# 3    washingtonexaminer                True  ... 2017-07-22 04:00:00+00:00
# 4    washingtonexaminer                True  ... 2017-05-10 04:00:00+00:00
# ..                  ...                 ...  ...                       ...
# 888             foxnews                True  ... 2020-07-02 04:00:00+00:00
# 889             foxnews                True  ... 2019-09-25 04:00:00+00:00
# 890       gatewaypundit                True  ... 2020-04-10 23:49:17+00:00
# 891       gatewaypundit                True  ... 2020-04-13 18:03:39+00:00
# 892       gatewaypundit                True  ... 2020-04-10 23:49:17+00:00
#
#                                                                                                                                    doc_title  \
# 0                                                                                     Freedom Caucus's reasonable demand on Obamacare repeal
# 1                                                           ICE: 124 illegal immigrants released from jail later charged in 138 murder cases
# 2                                                                     SW Border crisis: 95% of illegals, drugs get in from Mexico undetected
# 3                                                                      John McCain's daughter Meghan tweets picture: 'Amazing hike with Dad'
# 4                                                                           Aetna completely exits Obamacare exchanges, cites massive losses
# ..                                                                                                                                       ...
# 888                            Unemployment rate drops to 11.1% in June as job growth blows past expectations with 4.8M added | Fox Business
# 889                                                            US-Japan ink phase one of trade deal on $7 billion in US goods | Fox Business
# 890  Democrat Kentucky Governor Announces Plan to Record License Plates of Easter Church Goers and Force Them to Self-Quarantine for 14 Days
# 891                                                                GOP Rep. Massie Warns US is ‘Weeks Away, Not Months,’ From Food Shortages
# 892  Democrat Kentucky Governor Announces Plan to Record License Plates of Easter Church Goers and Force Them to Self-Quarantine for 14 Days
#
#                 doctype doctype_ideo doc_topic                      d0_doc_id  \
# 0    washingtonexaminer          est    topic3  WashingtonExaminer_1086525938
# 1    washingtonexaminer          est    topic2  WashingtonExaminer_1036420208
# 2    washingtonexaminer          est    topic1  WashingtonExaminer_1176603255
# 3    washingtonexaminer          est    topic2   WashingtonExaminer_919213962
# 4    washingtonexaminer          est    topic3   WashingtonExaminer_841955785
# ..                  ...          ...       ...                            ...
# 888             foxnews          est    topic3             FoxNews_1670966367
# 889             foxnews          est    topic1             FoxNews_1406587957
# 890       gatewaypundit          alt    topic2       GatewayPundit_1574890973
# 891       gatewaypundit          alt    topic1       GatewayPundit_1577329526
# 892       gatewaypundit          alt    topic2       GatewayPundit_1574890973
#
#              d0_doctype  dyad_pos d1_doc_id d1_doctype
# 0    washingtonexaminer       0.0      None       None
# 1    washingtonexaminer       0.0      None       None
# 2    washingtonexaminer       0.0      None       None
# 3    washingtonexaminer       0.0      None       None
# 4    washingtonexaminer       0.0      None       None
# ..                  ...       ...       ...        ...
# 888             foxnews       0.0      None       None
# 889             foxnews       0.0      None       None
# 890       gatewaypundit       0.0      None       None
# 891       gatewaypundit       0.0      None       None
# 892       gatewaypundit       0.0      None       None
#
# [893 rows x 29 columns]

# %%
with pd.option_context("display.max_colwidth", None):
    display(df_urls_d1)
# Out:
#                                      url_id          created_at  \
# 0       DesJarlaisTN04_859058573053186048_0 2017-05-01 14:54:59
# 1          SenTedCruz_1153377065275744256_0 2019-07-22 18:51:35
# 2      replouiegohmert_689917877424648192_0 2016-01-20 21:10:14
# 3          JohnCornyn_1066710361397702657_0 2018-11-25 15:09:03
# 4         SteveScalise_783727193406967808_0 2016-10-05 17:54:58
# ...                                     ...                 ...
# 1264  jasoninthehouse_1294638820449689604_0 2020-08-15 14:15:22
# 1265  jasoninthehouse_1280298580536745988_0 2020-07-07 00:32:23
# 1266     RepMattGaetz_1183871220967706624_0 2019-10-14 22:24:28
# 1267     RepMattGaetz_1176169365974265857_0 2019-09-23 16:20:03
# 1268     RepMattGaetz_1163904690481971202_0 2019-08-20 20:04:37
#
#      created_at_year         username  \
# 0         2017-01-01   DesJarlaisTN04
# 1         2019-01-01       SenTedCruz
# 2         2016-01-01  replouiegohmert
# 3         2018-01-01       JohnCornyn
# 4         2016-01-01     SteveScalise
# ...              ...              ...
# 1264      2020-01-01  jasoninthehouse
# 1265      2020-01-01  jasoninthehouse
# 1266      2019-01-01     RepMattGaetz
# 1267      2019-01-01     RepMattGaetz
# 1268      2019-01-01     RepMattGaetz
#
#                                                                                                                         standardized_url  \
# 0                                                     www.washingtonexaminer.com/trump-signs-executive-action-aimed-at-va-accountability
# 1     www.washingtonexaminer.com/news/ted-cruz-and-bill-cassidy-file-resolution-to-designate-antifa-as-a-domestic-terrorist-organization
# 2                                                        www.washingtonexaminer.com/dhs-500-000-people-overstayed-their-us-visas-in-2015
# 3             www.washingtonexaminer.com/opinion/columnists/byron-york-when-it-comes-to-undermining-faith-in-democracy-another-low-point
# 4                                                               www.washingtonexaminer.com/oklahoma-obamacare-plans-face-76-percent-hike
# ...                                                                                                                                  ...
# 1264                hannity.com/media-room/chicago-chaos-looters-attack-ronald-mcdonald-charity-house-with-sick-children-families-inside
# 1265                           hannity.com/media-room/grieving-father-they-say-black-lives-matter-you-killed-your-own-you-killed-a-child
# 1266                                      hannity.com/media-room/denied-entry-rep-matt-gaetz-kicked-out-of-democrats-impeachment-hearing
# 1267                                          hannity.com/media-room/gaetz-on-hannity-were-seeing-a-true-fissure-in-the-democratic-party
# 1268          www.thegatewaypundit.com/2019/08/rep-matt-gaetz-slams-taxpayer-funded-testing-using-aborted-fetuses-and-laboratory-animals
#
#                   url_netloc urlexpander_error               outlet  \
# 0     washingtonexaminer.com          no error  Washington Examiner
# 1     washingtonexaminer.com          no error  Washington Examiner
# 2     washingtonexaminer.com          no error  Washington Examiner
# 3     washingtonexaminer.com          no error  Washington Examiner
# 4     washingtonexaminer.com          no error  Washington Examiner
# ...                      ...               ...                  ...
# 1264             hannity.com          no error         Sean Hannity
# 1265             hannity.com          no error         Sean Hannity
# 1266             hannity.com          no error         Sean Hannity
# 1267             hannity.com          no error         Sean Hannity
# 1268    thegatewaypundit.com          no error   The Gateway Pundit
#
#               outlet_std  is_selected_outlet  ...          doc_publish_date  \
# 0     washingtonexaminer                True  ... 2017-04-27 04:00:00+00:00
# 1     washingtonexaminer                True  ... 2019-07-19 04:00:00+00:00
# 2     washingtonexaminer                True  ... 2016-01-20 02:04:19+00:00
# 3     washingtonexaminer                True  ... 2018-11-24 05:00:00+00:00
# 4     washingtonexaminer                True  ... 2016-10-05 00:00:21+00:00
# ...                  ...                 ...  ...                       ...
# 1264         seanhannity                True  ... 2020-08-13 15:11:57+00:00
# 1265         seanhannity                True  ... 2020-07-06 19:06:31+00:00
# 1266         seanhannity                True  ... 2019-10-14 21:33:22+00:00
# 1267         seanhannity                True  ... 2019-09-19 17:45:43+00:00
# 1268       gatewaypundit                True  ... 2019-08-20 19:16:49+00:00
#
#                                                                                                    doc_title  \
# 0                                                    Trump signs executive action aimed at VA accountability
# 1         Ted Cruz and Bill Cassidy file resolution to designate antifa as a domestic terrorist organization
# 2                                                    DHS: 500,000 people overstayed their U.S. visas in 2015
# 3                             Byron York: When it comes to undermining faith in democracy, another low point
# 4                                                              Oklahoma Obamacare plans face 76 percent hike
# ...                                                                                                      ...
# 1264         CHICAGO CHAOS: Looters Attack Ronald McDonald Charity House With Sick Children, Families Inside
# 1265  GRIEVING FATHER: ‘They Say Black Lives Matter? You Killed Your Own, You Killed a Child’ | Sean Hannity
# 1266             Denied Entry: Rep. Matt Gaetz ‘Kicked Out’ of Democrats’ Impeachment Hearing | Sean Hannity
# 1267                                   GAETZ ON HANNITY: We’re Seeing a True Fissure in the Democratic Party
# 1268              Rep. Matt Gaetz Slams Taxpayer-Funded Testing Using Aborted Fetuses and Laboratory Animals
#
#                  doctype doctype_ideo doc_topic  \
# 0     washingtonexaminer          est    topic1
# 1     washingtonexaminer          est    topic2
# 2     washingtonexaminer          est    topic2
# 3     washingtonexaminer          est    topic1
# 4     washingtonexaminer          est    topic2
# ...                  ...          ...       ...
# 1264         seanhannity          est    topic2
# 1265         seanhannity          est    topic1
# 1266         seanhannity          est    topic2
# 1267         seanhannity          est    topic2
# 1268       gatewaypundit          alt    topic2
#
#                           d0_doc_id          d0_doctype  dyad_pos  \
# 0             DailyCaller_615309601         dailycaller       1.0
# 1          GatewayPundit_1342539334       gatewaypundit       1.0
# 2           GatewayPundit_416550225       gatewaypundit       1.0
# 3                FoxNews_1072633614             foxnews       1.0
# 4                 Newsmax_713083039             newsmax       1.0
# ...                             ...                 ...       ...
# 1264             FoxNews_1681898986             foxnews       1.0
# 1265             FoxNews_1653721474             foxnews       1.0
# 1266       GatewayPundit_1418591085       gatewaypundit       1.0
# 1267             FoxNews_1394270710             foxnews       1.0
# 1268  WashingtonExaminer_1392393834  washingtonexaminer       1.0
#
#                           d1_doc_id          d1_doctype
# 0      WashingtonExaminer_822152161  washingtonexaminer
# 1     WashingtonExaminer_1356440915  washingtonexaminer
# 2      WashingtonExaminer_416560799  washingtonexaminer
# 3     WashingtonExaminer_1176656301  washingtonexaminer
# 4      WashingtonExaminer_521764106  washingtonexaminer
# ...                             ...                 ...
# 1264         SeanHannity_1682882148         seanhannity
# 1265         SeanHannity_1676620439         seanhannity
# 1266         SeanHannity_1468929651         seanhannity
# 1267         SeanHannity_1397363598         seanhannity
# 1268       GatewayPundit_1369896212       gatewaypundit
#
# [1269 rows x 29 columns]

# %%
df_dyadic_urls.groupby('url_id').size().sort_values(ascending=False)
# Out:
# url_id
# RepBrianBabin_1273741996511952899_0    2
# RepTomRice_750467868614090752_0        1
# RepTomEmmer_1281254311834648576_0      1
# RepTomGarrett_1111622761842180097_0    1
# RepTomGarrett_852171833336057856_0     1
#                                       ..
# RepEdRoyce_753687474111651842_0        1
# RepEdRoyce_1016680154419122177_0       1
# RepDougCollins_926425997813088256_0    1
# RepDougCollins_690297770465452032_0    1
# virginiafoxx_817372135480029184_0      1
# Length: 2161, dtype: int64

# %%
# One url_id is associated with 2 different clusters
# appears that Fox News' RSS feed posted the original on June 18, 2020 and re-posted an updated(?) version on July 9, 2020
with pd.option_context("display.max_colwidth", None):
    display(df_urls_d1.loc[df_urls_d1["url_id"]=="RepBrianBabin_1273741996511952899_0"])
# Out:
#                                   url_id          created_at created_at_year  \
# 912  RepBrianBabin_1273741996511952899_0 2020-06-18 22:18:51      2020-01-01
# 913  RepBrianBabin_1273741996511952899_0 2020-06-18 22:18:51      2020-01-01
#
#           username  \
# 912  RepBrianBabin
# 913  RepBrianBabin
#
#                                                                                             standardized_url  \
# 912  www.foxnews.com/politics/supreme-court-rules-against-trump-administration-over-move-to-end-daca-program
# 913  www.foxnews.com/politics/supreme-court-rules-against-trump-administration-over-move-to-end-daca-program
#
#       url_netloc urlexpander_error    outlet outlet_std  is_selected_outlet  \
# 912  foxnews.com          no error  Fox News    foxnews                True
# 913  foxnews.com          no error  Fox News    foxnews                True
#
#      ...                 doc_publish_date  \
# 912  ... 2020-07-09 06:45:36.108588+00:00
# 913  ...        2020-06-18 14:11:48+00:00
#
#                                                                                doc_title  \
# 912  Supreme Court rules against Trump administration bid to end DACA program | Fox News
# 913             Supreme Court rules against Trump administration bid to end DACA program
#
#      doctype doctype_ideo doc_topic                      d0_doc_id  \
# 912  foxnews          est    topic2  WashingtonExaminer_1656807117
# 913  foxnews          est    topic3         DailyCaller_1637707608
#
#              d0_doctype  dyad_pos           d1_doc_id d1_doctype
# 912  washingtonexaminer       1.0  FoxNews_1656855082    foxnews
# 913         dailycaller       1.0  FoxNews_1638393581    foxnews
#
# [2 rows x 29 columns]

# %%
# RepBrianBabin_1273741996511952899_0: drop more recent article within duplicate
df_urls_d1 = df_urls_d1[df_urls_d1['d1_doc_id'] != 'FoxNews_1656855082'].reset_index(drop=True)

# %%
len(df_urls_d0) + len(df_urls_d1)
# Out:
# 2161

# %%
# df_urls_d1: (re-)tweet was associated with 'follower' instance
df_urls_d1.to_pickle(os.path.join(urls_dir, "indirect_shared_domains_through_dyads.pkl"))

# %% [markdown]
# ### 3. Plot "follower" URLs

# %%
len(df_urls_d1)
# Out:
# 1268

# %%
# %matplotlib inline

# %%
# Politicians' Indirect (Re-)Tweets by 'Lead' Outlet (Colored by 'Follower' Outlet)
plt_indirect = (p9.ggplot(data=df_urls_d1,
                    mapping=p9.aes(x='created_at_year'))
                 + p9.geom_bar(p9.aes(fill='ideo_subcategory'), stat='count', # ideo_subcategory is for d1
                            alpha = 0.5)
                 + p9.scale_fill_manual(values=['darkorange', 'firebrick', 'steelblue', 'grey'])
                 + p9.geom_text(
                     p9.aes(label=p9.after_stat('count')),
                     stat='count',
                     va='bottom',
                     size=8
                 )
                 + p9.scale_x_datetime(labels=date_format("'%y"), date_breaks='4 years')
                 + p9.scale_y_continuous(expand=(0, 0, 0, 50))
                 + p9.facet_wrap("d0_doctype", labeller='label_value', ncol=3)
                 + p9.theme(figure_size=(5.75, 6.0),
                     subplots_adjust={'wspace': 0.10,
                                      'hspace': 0.30
                                     })
                 + p9.labs(title="Politicians' Indirect (Re-)Tweets by 'Lead' Outlet",
                        fill='',
                        x='year',
                        y='count of (re-)tweets')
                )

display(plt_indirect)
# Out:
# <ggplot: (8781031737194)>

# %%
save_image(plt_indirect, "outlets_right_shared_by_year_indirect", width=5.75, height=6.0, units="in")
# Out:
# /home/jovyan/.local/lib/python3.8/site-packages/plotnine/ggplot.py:719: PlotnineWarning: Saving 5.75 x 6.0 in image.
# /home/jovyan/.local/lib/python3.8/site-packages/plotnine/ggplot.py:722: PlotnineWarning: Filename: ../../figures/indirect/png/outlets_right_shared_by_year_indirect.png

# %%
df_urls_d1.columns
# Out:
# Index(['url_id', 'created_at', 'created_at_year', 'username',
#        'standardized_url', 'url_netloc', 'urlexpander_error', 'outlet',
#        'outlet_std', 'is_selected_outlet', 'pew_libdem', 'pew_consrep',
#        'pew_libdem_consrep_diff', 'ideo_category', 'ideo_subcategory',
#        'ideo_left2right', 'cluster_id', 'cluster_size', 'doc_id',
#        'doc_publish_date', 'doc_title', 'doctype', 'doctype_ideo', 'doc_topic',
#        'd0_doc_id', 'd0_doctype', 'dyad_pos', 'd1_doc_id', 'd1_doctype'],
#       dtype='object')

# %%
with pd.option_context('display.max_colwidth', None):
    display(df_urls_d1.loc[df_urls_d1['d0_doctype']=='americanrenaissance'])
# Out:
#                                   url_id          created_at created_at_year  \
# 354  RepLoudermilk_1217840618078113799_0 2020-01-16 16:06:44      2020-01-01
# 438  RepBrianBabin_1217933512738852865_0 2020-01-16 22:15:52      2020-01-01
# 817   RepMarkWalker_824362661508943873_0 2017-01-25 21:05:49      2017-01-01
#
#           username  \
# 354  RepLoudermilk
# 438  RepBrianBabin
# 817  RepMarkWalker
#
#                                                                                                        standardized_url  \
# 354                                                       www.foxnews.com/politics/nyc-sanctuary-city-policy-under-fire
# 438                                                       www.foxnews.com/politics/nyc-sanctuary-city-policy-under-fire
# 817  www.foxnews.com/politics/education-department-report-finds-billions-spent-under-obama-had-no-impact-on-achievement
#
#       url_netloc urlexpander_error    outlet outlet_std  is_selected_outlet  \
# 354  foxnews.com          no error  Fox News    foxnews                True
# 438  foxnews.com          no error  Fox News    foxnews                True
# 817  foxnews.com          no error  Fox News    foxnews                True
#
#      ...          doc_publish_date  \
# 354  ... 2020-01-16 05:00:00+00:00
# 438  ... 2020-01-16 05:00:00+00:00
# 817  ... 2017-01-25 14:47:00+00:00
#
#                                                                                                          doc_title  \
# 354  NYC’s sanctuary city policy under fire after freed illegal immigrant allegedly murders 92-year-old | Fox News
# 438  NYC’s sanctuary city policy under fire after freed illegal immigrant allegedly murders 92-year-old | Fox News
# 817                    Education Department report finds billions spent under Obama had 'no impact' on achievement
#
#      doctype doctype_ideo doc_topic                       d0_doc_id  \
# 354  foxnews          est    topic1  AmericanRenaissance_1495026172
# 438  foxnews          est    topic1  AmericanRenaissance_1495026172
# 817  foxnews          est    topic1   AmericanRenaissance_571311262
#
#               d0_doctype  dyad_pos           d1_doc_id d1_doctype
# 354  americanrenaissance       1.0  FoxNews_1517170333    foxnews
# 438  americanrenaissance       1.0  FoxNews_1517170333    foxnews
# 817  americanrenaissance       1.0   FoxNews_572052805    foxnews
#
# [3 rows x 29 columns]

# %%
with pd.option_context('display.max_colwidth', None):
    display(df_urls_d1.loc[df_urls_d1['d0_doctype']=='dailystormer'])
# Out:
#                                    url_id          created_at created_at_year  \
# 714  SenHawleyPress_1255975777528619009_0 2020-04-30 21:42:14      2020-01-01
# 994        DrPhilRoe_829852767086850048_0 2017-02-10 00:41:32      2017-01-01
#
#            username  \
# 714  SenHawleyPress
# 994       DrPhilRoe
#
#                                                                                                standardized_url  \
# 714                             www.foxnews.com/politics/hawley-meatpacking-titans-coronavirus-monopoly-farmers
# 994  www.foxnews.com/politics/defiant-trump-tweets-see-you-in-court-after-ruling-again-blocks-immigration-order
#
#       url_netloc urlexpander_error    outlet outlet_std  is_selected_outlet  \
# 714  foxnews.com          no error  Fox News    foxnews                True
# 994  foxnews.com          no error  Fox News    foxnews                True
#
#      ...          doc_publish_date  \
# 714  ... 2020-04-29 20:09:12+00:00
# 994  ... 2017-02-09 12:00:00+00:00
#
#                                                                                  doc_title  \
# 714  Hawley eyes meatpacking titans amid coronavirus crisis: 'Monopoly is bad for farmers'
# 994    Defiant Trump tweets 'SEE YOU IN COURT' after ruling again blocks immigration order
#
#      doctype doctype_ideo doc_topic                d0_doc_id    d0_doctype  \
# 714  foxnews          est    topic1  DailyStormer_1590014524  dailystormer
# 994  foxnews          est    topic1   DailyStormer_576843628  dailystormer
#
#      dyad_pos           d1_doc_id d1_doctype
# 714       1.0  FoxNews_1592642771    foxnews
# 994       1.0   FoxNews_694938422    foxnews
#
# [2 rows x 29 columns]

# %%
with pd.option_context('display.max_colwidth', None):
    display(df_urls_d1.loc[df_urls_d1['d0_doctype']=='infowars'])
# Out:
#                                      url_id          created_at  \
# 156          RepGosar_1222171207967133696_0 2020-01-28 14:54:57
# 213          RepGosar_1145749040618856448_0 2019-07-01 17:40:32
# 297   MarshaBlackburn_1306976793665122305_0 2020-09-18 15:22:04
# 299     RepMarkWalker_1002606487242530816_0 2018-06-01 17:43:08
# 321   RepThomasMassie_1283851374820818952_0 2020-07-16 19:49:55
# 350      SenTomCotton_1250569296272637952_0 2020-04-15 23:38:49
# 355   SenatorLoeffler_1253015540488118274_0 2020-04-22 17:39:19
# 400   SenatorLoeffler_1325507188450861057_0 2020-11-08 18:35:15
# 461      RepMattGaetz_1186276249498505216_0 2019-10-21 13:41:12
# 497   SenatorLoeffler_1311072237685014530_0 2020-09-29 22:35:54
# 505   RepThomasMassie_1283850176545857539_0 2020-07-16 19:45:09
# 517   RepRickCrawford_1250592464857153536_0 2020-04-16 01:10:53
# 519   RepThomasMassie_1283850548714905601_0 2020-07-16 19:46:38
# 587          RepGosar_1250586183786258433_0 2020-04-16 00:45:55
# 591    RepAndyBiggsAZ_1185627621033480192_0 2019-10-19 18:43:47
# 681       RepJimBanks_1251217718339989504_0 2020-04-17 18:35:25
# 753   RepThomasMassie_1283808297125064706_0 2020-07-16 16:58:44
# 791       RepJimBanks_1250567947510321152_0 2020-04-15 23:33:27
# 861    DesJarlaisTN04_1250850794909417473_0 2020-04-16 18:17:23
# 956      RepMarkGreen_1250579289545850880_0 2020-04-16 00:18:31
# 964    jasoninthehouse_867866246783655936_0 2017-05-25 22:13:32
# 977     RepBrianBabin_1280639698352967680_0 2020-07-07 23:07:51
# 1026  SenatorLoeffler_1309285550994710528_0 2020-09-25 00:16:15
# 1038  CongressmanHice_1250599305167151105_0 2020-04-16 01:38:04
# 1041      RepRWilliams_997854400029708290_0 2018-05-19 15:00:02
# 1142         RandPaul_1154970702979772416_0 2019-07-27 04:24:08
# 1220      RepMoBrooks_1090814950954680320_0 2019-01-31 03:32:05
# 1227         RepGosar_1140730250005024768_0 2019-06-17 21:17:40
# 1242     RepMattGaetz_1288148990433865728_0 2020-07-28 16:27:06
#
#      created_at_year         username  \
# 156       2020-01-01         RepGosar
# 213       2019-01-01         RepGosar
# 297       2020-01-01  MarshaBlackburn
# 299       2018-01-01    RepMarkWalker
# 321       2020-01-01  RepThomasMassie
# 350       2020-01-01     SenTomCotton
# 355       2020-01-01  SenatorLoeffler
# 400       2020-01-01  SenatorLoeffler
# 461       2019-01-01     RepMattGaetz
# 497       2020-01-01  SenatorLoeffler
# 505       2020-01-01  RepThomasMassie
# 517       2020-01-01  RepRickCrawford
# 519       2020-01-01  RepThomasMassie
# 587       2020-01-01         RepGosar
# 591       2019-01-01   RepAndyBiggsAZ
# 681       2020-01-01      RepJimBanks
# 753       2020-01-01  RepThomasMassie
# 791       2020-01-01      RepJimBanks
# 861       2020-01-01   DesJarlaisTN04
# 956       2020-01-01     RepMarkGreen
# 964       2017-01-01  jasoninthehouse
# 977       2020-01-01    RepBrianBabin
# 1026      2020-01-01  SenatorLoeffler
# 1038      2020-01-01  CongressmanHice
# 1041      2018-01-01     RepRWilliams
# 1142      2019-01-01         RandPaul
# 1220      2019-01-01      RepMoBrooks
# 1227      2019-01-01         RepGosar
# 1242      2020-01-01     RepMattGaetz
#
#                                                                                                                               standardized_url  \
# 156                                                                          dailycaller.com/2020/01/27/don-lemon-cnn-panel-laugh-trump-voters
# 213                                                                       dailycaller.com/2019/06/29/new-york-times-public-shame-border-agents
# 297                   www.foxnews.com/politics/tucker-carlson-says-alleged-nashville-coronavirus-data-cover-up-other-obfuscations-unforgivable
# 299                               www.foxnews.com/politics/trump-says-singapore-summit-with-kim-is-back-on-after-meeting-north-korean-official
# 321                                                                       www.foxnews.com/media/massie-house-gop-remove-all-troops-afghanistan
# 350                                                                    www.foxnews.com/politics/coronavirus-wuhan-lab-china-compete-us-sources
# 355     www.foxnews.com/politics/loeffler-urges-trump-administration-to-demand-significant-concessions-in-us-china-trade-deal-amid-coronavirus
# 400                                                         www.foxnews.com/politics/loeffler-bill-ramp-up-penalties-for-election-interference
# 461                                                                                           www.foxnews.com/opinion/biggs-and-gaetz-on-syria
# 497                                                         www.foxnews.com/politics/loeffler-bill-ramp-up-penalties-for-election-interference
# 505                                                                       www.foxnews.com/media/massie-house-gop-remove-all-troops-afghanistan
# 517                                                                    www.foxnews.com/politics/coronavirus-wuhan-lab-china-compete-us-sources
# 519                                                                       www.foxnews.com/media/massie-house-gop-remove-all-troops-afghanistan
# 587                                                                    www.foxnews.com/politics/coronavirus-wuhan-lab-china-compete-us-sources
# 591                                                                                           www.foxnews.com/opinion/biggs-and-gaetz-on-syria
# 681                                                                  www.foxnews.com/politics/us-officials-investigation-coronavirus-wuhan-lab
# 753                                                                       www.foxnews.com/media/massie-house-gop-remove-all-troops-afghanistan
# 791                                                                    www.foxnews.com/politics/coronavirus-wuhan-lab-china-compete-us-sources
# 861                                                                    www.foxnews.com/politics/coronavirus-wuhan-lab-china-compete-us-sources
# 956                                                                    www.foxnews.com/politics/coronavirus-wuhan-lab-china-compete-us-sources
# 964                                   www.foxnews.com/politics/obamas-nsa-rebuked-for-snooping-on-americans-journo-says-it-proves-wide-pattern
# 977                                                                        www.foxnews.com/world/who-china-bubonic-plague-carefully-monitoring
# 1026                                                        www.foxnews.com/politics/loeffler-bill-ramp-up-penalties-for-election-interference
# 1038                                                                   www.foxnews.com/politics/coronavirus-wuhan-lab-china-compete-us-sources
# 1041                     www.foxnews.com/politics/trump-administration-set-to-resurrect-ban-on-abortion-counseling-at-federally-funded-clinics
# 1142                     www.breitbart.com/politics/2019/07/26/rand-paul-maybe-ilhan-omar-would-appreciate-america-more-if-she-visited-somalia
# 1220  www.breitbart.com/politics/2019/01/30/exclusive-mo-brooks-trump-ought-to-declare-a-national-emergency-build-the-wall-save-american-lives
# 1227                                         www.breitbart.com/clips/2019/06/16/trump-obama-had-to-know-of-setup-to-block-his-presidential-bid
# 1242                             www.breitbart.com/tech/2020/07/27/rep-matt-gaetz-files-criminal-referral-against-facebook-ceo-mark-zuckerberg
#
#            url_netloc urlexpander_error        outlet   outlet_std  \
# 156   dailycaller.com          no error  Daily Caller  dailycaller
# 213   dailycaller.com          no error  Daily Caller  dailycaller
# 297       foxnews.com          no error      Fox News      foxnews
# 299       foxnews.com          no error      Fox News      foxnews
# 321       foxnews.com          no error      Fox News      foxnews
# 350       foxnews.com          no error      Fox News      foxnews
# 355       foxnews.com          no error      Fox News      foxnews
# 400       foxnews.com          no error      Fox News      foxnews
# 461       foxnews.com          no error      Fox News      foxnews
# 497       foxnews.com          no error      Fox News      foxnews
# 505       foxnews.com          no error      Fox News      foxnews
# 517       foxnews.com          no error      Fox News      foxnews
# 519       foxnews.com          no error      Fox News      foxnews
# 587       foxnews.com          no error      Fox News      foxnews
# 591       foxnews.com          no error      Fox News      foxnews
# 681       foxnews.com          no error      Fox News      foxnews
# 753       foxnews.com          no error      Fox News      foxnews
# 791       foxnews.com          no error      Fox News      foxnews
# 861       foxnews.com          no error      Fox News      foxnews
# 956       foxnews.com          no error      Fox News      foxnews
# 964       foxnews.com          no error      Fox News      foxnews
# 977       foxnews.com          no error      Fox News      foxnews
# 1026      foxnews.com          no error      Fox News      foxnews
# 1038      foxnews.com          no error      Fox News      foxnews
# 1041      foxnews.com          no error      Fox News      foxnews
# 1142    breitbart.com          no error     Breitbart    breitbart
# 1220    breitbart.com          no error     Breitbart    breitbart
# 1227    breitbart.com          no error     Breitbart    breitbart
# 1242    breitbart.com          no error     Breitbart    breitbart
#
#       is_selected_outlet  ...          doc_publish_date  \
# 156                 True  ... 2020-01-28 04:41:30+00:00
# 213                 True  ... 2019-06-29 17:25:11+00:00
# 297                 True  ... 2020-09-18 09:18:19+00:00
# 299                 True  ... 2018-06-01 15:47:00+00:00
# 321                 True  ... 2020-07-16 14:05:33+00:00
# 350                 True  ... 2020-04-15 23:07:06+00:00
# 355                 True  ... 2020-04-22 16:38:12+00:00
# 400                 True  ... 2020-09-24 22:15:07+00:00
# 461                 True  ... 2019-10-19 02:34:09+00:00
# 497                 True  ... 2020-09-24 22:15:07+00:00
# 505                 True  ... 2020-07-16 14:05:33+00:00
# 517                 True  ... 2020-04-15 23:07:06+00:00
# 519                 True  ... 2020-07-16 14:05:33+00:00
# 587                 True  ... 2020-04-15 23:07:06+00:00
# 591                 True  ... 2019-10-19 02:34:09+00:00
# 681                 True  ... 2020-04-17 18:05:18+00:00
# 753                 True  ... 2020-07-16 14:05:33+00:00
# 791                 True  ... 2020-04-15 23:07:06+00:00
# 861                 True  ... 2020-04-15 23:07:06+00:00
# 956                 True  ... 2020-04-15 23:07:06+00:00
# 964                 True  ... 2017-05-25 18:04:00+00:00
# 977                 True  ... 2020-07-07 17:51:55+00:00
# 1026                True  ... 2020-09-24 22:15:07+00:00
# 1038                True  ... 2020-04-15 23:07:06+00:00
# 1041                True  ... 2018-05-18 04:15:00+00:00
# 1142                True  ... 2019-07-26 22:42:57+00:00
# 1220                True  ... 2019-01-30 23:46:06+00:00
# 1227                True  ... 2019-06-16 14:58:49+00:00
# 1242                True  ... 2020-07-27 23:26:54+00:00
#
#                                                                                                                      doc_title  \
# 156                                      It Took This CNN Panel Just 80 Seconds To Show What They Really Think Of Trump Voters
# 213                                                             NYT Op-Ed Calls For Public Shaming Of Border Protection Agents
# 297                       Tucker Carlson says alleged Nashville coronavirus data 'cover-up,' other obfuscations 'unforgivable'
# 299                                            North Korean official arrives at White House to deliver letter from Kim Jong Un
# 321   Rep. Massie among Republicans pushing Trump to remove all troops from Afghanistan: 'Not worth one more Gold Star family'
# 350                          Sources believe coronavirus originated in Wuhan lab as part of China's efforts to compete with US
# 355       Sen. Loeffler urges Trump administration to demand 'significant concessions' in US-China trade deal amid coronavirus
# 400                    Loeffler introduces bill to ramp up penalties for election interference, amid fears of ballot tampering
# 461               Reps. Biggs and Gaetz: Trump fulfilling campaign pledge and saving US lives by pulling military out of Syria
# 497                    Loeffler introduces bill to ramp up penalties for election interference, amid fears of ballot tampering
# 505   Rep. Massie among Republicans pushing Trump to remove all troops from Afghanistan: 'Not worth one more Gold Star family'
# 517                          Sources believe coronavirus originated in Wuhan lab as part of China's efforts to compete with US
# 519   Rep. Massie among Republicans pushing Trump to remove all troops from Afghanistan: 'Not worth one more Gold Star family'
# 587                          Sources believe coronavirus originated in Wuhan lab as part of China's efforts to compete with US
# 591               Reps. Biggs and Gaetz: Trump fulfilling campaign pledge and saving US lives by pulling military out of Syria
# 681                                US officials confirm full-scale investigation of whether coronavirus escaped from Wuhan lab
# 753   Rep. Massie among Republicans pushing Trump to remove all troops from Afghanistan: 'Not worth one more Gold Star family'
# 791                          Sources believe coronavirus originated in Wuhan lab as part of China's efforts to compete with US
# 861                          Sources believe coronavirus originated in Wuhan lab as part of China's efforts to compete with US
# 956                          Sources believe coronavirus originated in Wuhan lab as part of China's efforts to compete with US
# 964                                          Obama’s NSA rebuked for snooping on Americans; journo says it proves wide pattern
# 977                               WHO praises China for handling of bubonic plague, says it's 'carefully monitoring' situation
# 1026                   Loeffler introduces bill to ramp up penalties for election interference, amid fears of ballot tampering
# 1038                         Sources believe coronavirus originated in Wuhan lab as part of China's efforts to compete with US
# 1041                              Trump administration set to resurrect ban on abortion counseling at federally-funded clinics
# 1142                                        Rand Paul: Maybe Ilhan Omar Would 'Appreciate America More' if She Visited Somalia
# 1220                   Exclusive—Mo Brooks: Trump ‘Ought to Declare a National Emergency,’ Build the Wall, Save American Lives
# 1227                                                       Trump: Obama 'Had to Know' of 'Setup' to Block His Presidential Bid
# 1242                                              Rep. Matt Gaetz Files Criminal Referral Against Facebook CEO Mark Zuckerberg
#
#           doctype doctype_ideo doc_topic            d0_doc_id d0_doctype  \
# 156   dailycaller          est    topic3  InfoWars_1505235758   infowars
# 213   dailycaller          est    topic1  InfoWars_1325367126   infowars
# 297       foxnews          est    topic3  InfoWars_1714032297   infowars
# 299       foxnews          est    topic1   InfoWars_881457108   infowars
# 321       foxnews          est    topic1  InfoWars_1661154791   infowars
# 350       foxnews          est    topic3  InfoWars_1577995458   infowars
# 355       foxnews          est    topic2  InfoWars_1577995458   infowars
# 400       foxnews          est    topic2  InfoWars_1718258487   infowars
# 461       foxnews          est    topic3  InfoWars_1417260086   infowars
# 497       foxnews          est    topic2  InfoWars_1718258487   infowars
# 505       foxnews          est    topic1  InfoWars_1661154791   infowars
# 517       foxnews          est    topic3  InfoWars_1577995458   infowars
# 519       foxnews          est    topic1  InfoWars_1661154791   infowars
# 587       foxnews          est    topic3  InfoWars_1577995458   infowars
# 591       foxnews          est    topic3  InfoWars_1417260086   infowars
# 681       foxnews          est    topic3  InfoWars_1577995458   infowars
# 753       foxnews          est    topic1  InfoWars_1661154791   infowars
# 791       foxnews          est    topic3  InfoWars_1577995458   infowars
# 861       foxnews          est    topic3  InfoWars_1577995458   infowars
# 956       foxnews          est    topic3  InfoWars_1577995458   infowars
# 964       foxnews          est    topic2   InfoWars_806002973   infowars
# 977       foxnews          est    topic1  InfoWars_1654106462   infowars
# 1026      foxnews          est    topic2  InfoWars_1718258487   infowars
# 1038      foxnews          est    topic3  InfoWars_1577995458   infowars
# 1041      foxnews          est    topic2   InfoWars_876609754   infowars
# 1142    breitbart          alt    topic3  InfoWars_1349400324   infowars
# 1220    breitbart          alt    topic3  InfoWars_1179524865   infowars
# 1227    breitbart          alt    topic3  InfoWars_1313085950   infowars
# 1242    breitbart          alt    topic2  InfoWars_1671108861   infowars
#
#       dyad_pos               d1_doc_id   d1_doctype
# 156        1.0  DailyCaller_1506779782  dailycaller
# 213        1.0  DailyCaller_1325348705  dailycaller
# 297        1.0      FoxNews_1714611182      foxnews
# 299        1.0       FoxNews_890466270      foxnews
# 321        1.0      FoxNews_1663794983      foxnews
# 350        1.0      FoxNews_1579286418      foxnews
# 355        1.0      FoxNews_1585924829      foxnews
# 400        1.0      FoxNews_1720568671      foxnews
# 461        1.0      FoxNews_1422868504      foxnews
# 497        1.0      FoxNews_1720568671      foxnews
# 505        1.0      FoxNews_1663794983      foxnews
# 517        1.0      FoxNews_1579286418      foxnews
# 519        1.0      FoxNews_1663794983      foxnews
# 587        1.0      FoxNews_1579286418      foxnews
# 591        1.0      FoxNews_1422868504      foxnews
# 681        1.0      FoxNews_1581341281      foxnews
# 753        1.0      FoxNews_1663794983      foxnews
# 791        1.0      FoxNews_1579286418      foxnews
# 861        1.0      FoxNews_1579286418      foxnews
# 956        1.0      FoxNews_1579286418      foxnews
# 964        1.0       FoxNews_630538308      foxnews
# 977        1.0      FoxNews_1655429721      foxnews
# 1026       1.0      FoxNews_1720568671      foxnews
# 1038       1.0      FoxNews_1579286418      foxnews
# 1041       1.0       FoxNews_877938292      foxnews
# 1142       1.0    Breitbart_1349620917    breitbart
# 1220       1.0    Breitbart_1179623481    breitbart
# 1227       1.0    Breitbart_1313047052    breitbart
# 1242       1.0    Breitbart_1695607072    breitbart
#
# [29 rows x 29 columns]
