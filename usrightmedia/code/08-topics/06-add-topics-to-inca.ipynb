# %% [markdown]
# ## 06-add-topics-to-inca
#
# **Purpose**: Add topic assignments from multiple topic models into the ES documents which contain the right-wing media outlets' articles.
#
# **Steps**:
# 1. Create a list of dictionaries where each dict corresponds to a `doc_id`.
# 2. Each dict contains the `doc_id` and and multiple topic model-related keys.
#
#     - `lda_tfidf_texts_10_top_topic`
#     - `lda_tfidf_texts_10_top_topic_pct`
#     - `lda_tfidf_texts_10_topic_tokens`
#     - `lda_tfidf_texts_10_doc_tokens`
#
#     - `lda_tfidf_texts_25_top_topic`
#     - `lda_tfidf_texts_25_top_topic_pct`
#     - `lda_tfidf_texts_25_topic_tokens`
#     - `lda_tfidf_texts_25_doc_tokens`
#
#     - `lda_tfidf_texts_40_top_topic`
#     - `lda_tfidf_texts_40_top_topic_pct`
#     - `lda_tfidf_texts_40_topic_tokens`
#     - `lda_tfidf_texts_40_doc_tokens`
#
# 3. INCA has already been modified so it can update a document based on a `doc_id` and add multiple new fields in one-go (per [05-softcosine-clusters-inca.ipynb](https://github.com/wlmwng/us-right-media/blob/develop/usrightmedia/code/07-newsevents/)).

# %%
import os
import pandas as pd
import copy

from usrightmedia.shared.topics_utils import *

# %%
from usrightmedia.shared.loggers import get_logger
LOGGER = get_logger(filename = '06-add-topics-to-inca', logger_type='main')

# %%
from inca import Inca
myinca = Inca()
# Out:
# 2022-12-07 06:36:33,449 - [WARNING] - INCA - (hype_analysis.py).<module>(21) - $DISPLAY environment variable is not set, trying a different approach. You probably are running INCA on a text console, right?
# 2022-12-07 06:36:33,454 - [WARNING] - INCA - (var_tsa_analysis.py).<module>(21) - $DISPLAY environment variable is not set, trying a different approach. You probably are running INCA on a text console, right?

# %% [markdown]
# ### 1.0 Load `doc_id`s and topic assignments

# %%
def load(model):
    df = pd.read_pickle(os.path.join(MODELS_DIR, model, f"{model}_top_topic_with_ids.pkl"))
    # https://stackoverflow.com/a/70311963: add prefix to all columns except doc_id
    df = df.set_index('doc_id').add_prefix(f'lda_tfidf_texts_{model.split("_")[-1]}_').reset_index()
    return df

# %%
# %%time
df10 = load('lda_corpus_tfidf_docs_texts_topics_10')
df25 = load('lda_corpus_tfidf_docs_texts_topics_25')
df40 = load('lda_corpus_tfidf_docs_texts_topics_40')
# Out:
# CPU times: user 53.1 s, sys: 7.52 s, total: 1min
# Wall time: 1min

# %%
df10
# Out:
#                                 doc_id  lda_tfidf_texts_10_top_topic  \
# 0       AmericanRenaissance_1128638341                           0.0
# 1                  Breitbart_621129461                           0.0
# 2                 Breitbart_1483020896                           1.0
# 3                 Breitbart_1483567174                           1.0
# 4       AmericanRenaissance_1812166693                           2.0
# ...                                ...                           ...
# 727660    WashingtonExaminer_999923116                           0.0
# 727661    WashingtonExaminer_999923435                           0.0
# 727662    WashingtonExaminer_999951831                           2.0
# 727663    WashingtonExaminer_999952161                           2.0
# 727664    WashingtonExaminer_999966815                           2.0
#
#         lda_tfidf_texts_10_top_topic_pct  \
# 0                              91.110001
# 1                              88.419998
# 2                              69.800003
# 3                              58.980000
# 4                              63.770000
# ...                                  ...
# 727660                         56.650002
# 727661                         94.099998
# 727662                         56.059998
# 727663                         90.060005
# 727664                         89.690002
#
#                           lda_tfidf_texts_10_topic_tokens  \
# 0       police, people, man, white, officer, black, at...
# 1       police, people, man, white, officer, black, at...
# 2       coronavirus, virus, health, game, pandemic, va...
# 3       coronavirus, virus, health, game, pandemic, va...
# 4       investigation, russian, election, email, campa...
# ...                                                   ...
# 727660  police, people, man, white, officer, black, at...
# 727661  police, people, man, white, officer, black, at...
# 727662  investigation, russian, election, email, campa...
# 727663  investigation, russian, election, email, campa...
# 727664  investigation, russian, election, email, campa...
#
#                             lda_tfidf_texts_10_doc_tokens
# 0       [federal, government, study, reparation, desce...
# 1       [portrait, break, county, headquarters, vandal...
# 2       [death, sharply, american, community, multinat...
# 3       [ride, giant, courier, service, lawsuit, brake...
# 4       [dark, money, network, life, nearly, taxpayer,...
# ...                                                   ...
# 727660  [host, border, official, appalling, federal, l...
# 727661  [evening, struggle, civil, right, history, tim...
# 727662  [cohost, recently, commander, chief, pornograp...
# 727663  [federal, judge, person, special, counsel, inv...
# 727664  [famed, lawyer, oath, sexual, misconduct, alle...
#
# [727665 rows x 5 columns]

# %% [markdown]
# #### 1.1 Convert dataframes to dictionaries

# %%
# %%time
d10 = df10.to_dict("records")
d25 = df25.to_dict("records")
d40 = df40.to_dict("records")
# Out:
# CPU times: user 23.4 s, sys: 199 ms, total: 23.6 s
# Wall time: 23.5 s

# %%
d10[-5:-3]
# Out:
# [{'doc_id': 'WashingtonExaminer_999923116',
#   'lda_tfidf_texts_10_top_topic': 0.0,
#   'lda_tfidf_texts_10_top_topic_pct': 56.650001525878906,
#   'lda_tfidf_texts_10_topic_tokens': 'police, people, man, white, officer, black, attack, military, country, gun',
#   'lda_tfidf_texts_10_doc_tokens': ['host',
#    'border',
#    'official',
#    'appalling',
#    'federal',
#    'law',
#    'enforcement',
#    'officer',
#    'life',
#    'line',
#    'american',
#    'people',
#    'safe',
#    'nazi',
#    'spokesman',
#    'type',
#    'inflammatory',
#    'unacceptable',
#    'rhetoric',
#    'target',
#    'back',
#    'great',
#    'law',
#    'enforcement',
#    'episode',
#    'border',
#    'agent',
#    'illegal',
#    'immigrant',
#    'parent',
#    'child',
#    'family',
#    'press',
#    'secretary',
#    'child',
#    'mother',
#    'arm',
#    'breast',
#    'child',
#    'away',
#    'shower',
#    'away',
#    'shower',
#    'people',
#    'shower',
#    'trick',
#    'room',
#    'well',
#    'shower',
#    'right',
#    'spokesman',
#    'comment',
#    'inappropriate',
#    'apology',
#    'job',
#    'obviously',
#    'totally',
#    'inappropriate',
#    'hyperbolic',
#    'line',
#    'insensitive',
#    'disrespectful',
#    'official',
#    'remark',
#    'apology',
#    'feeling',
#    'tolerance',
#    'immigration',
#    'policy',
#    'prosecution',
#    'illegal',
#    'entrant',
#    'official',
#    'policy',
#    'family',
#    'purpose',
#    'illegal',
#    'alien',
#    'adult',
#    'citizen',
#    'crime',
#    'family',
#    'american',
#    'citizen',
#    'law',
#    'child',
#    'unclear',
#    'illegal',
#    'alien',
#    'right',
#    'american',
#    'citizen',
#    'phone',
#    'reporter',
#    'official',
#    'press',
#    'story',
#    'policy',
#    'accurately',
#    'process',
#    'story',
#    'negative',
#    'factually',
#    'negative',
#    'official',
#    'reporter',
#    'focus',
#    'actual',
#    'issue',
#    'anecdotal',
#    'exaggerated',
#    'fictional',
#    'story',
#    'official',
#    'string',
#    'unrelated',
#    'report',
#    'controversial',
#    'event',
#    'place',
#    'result',
#    'tolerance',
#    'policy',
#    'minor',
#    'adult',
#    'illegally',
#    'port',
#    'entry',
#    'child',
#    'parent',
#    'policy',
#    'official',
#    'example',
#    'official',
#    'age',
#    'baby',
#    'old',
#    'mother',
#    'official',
#    'report',
#    'parent',
#    'child',
#    'little',
#    'chance',
#    'different',
#    'facility',
#    'possible',
#    'context',
#    'parent',
#    'individual',
#    'jail',
#    'setting',
#    'person',
#    'prison',
#    'setting',
#    'parent',
#    'able',
#    'outside',
#    'party',
#    'discretion',
#    'facility',
#    'spokesman',
#    'american',
#    'citizen',
#    'detention',
#    'type',
#    'crime',
#    'ability',
#    'report',
#    'official',
#    'facility',
#    'clean',
#    'drinking',
#    'water',
#    'available',
#    'completely',
#    'false',
#    'official',
#    'high',
#    'quality',
#    'detention',
#    'center',
#    'world',
#    'child',
#    'official',
#    'false',
#    'report',
#    'minor',
#    'adult',
#    'port',
#    'entry',
#    'place',
#    'noncitizen',
#    'asylum',
#    'illegal',
#    'entry',
#    'condition',
#    'party',
#    'child',
#    'danger',
#    'parent',
#    'illegal',
#    'entry',
#    'parent',
#    'prosecution',
#    'chance',
#    'goodbye',
#    'child',
#    'agent',
#    'kid',
#    'away',
#    'parent',
#    'untrue',
#    'personnel',
#    'proficient',
#    'training',
#    'language',
#    'barrier',
#    'able',
#    'short',
#    'adult',
#    'prosecution',
#    'number',
#    'time',
#    'law_enforcement',
#    'law_enforcement',
#    'illegal_immigrant',
#    'press_secretary',
#    'illegal_entrant',
#    'illegal_alien',
#    'illegal_alien',
#    'tolerance_policy',
#    'port_entry',
#    'clean_drinking',
#    'detention_center',
#    'port_entry']},
#  {'doc_id': 'WashingtonExaminer_999923435',
#   'lda_tfidf_texts_10_top_topic': 0.0,
#   'lda_tfidf_texts_10_top_topic_pct': 94.0999984741211,
#   'lda_tfidf_texts_10_topic_tokens': 'police, people, man, white, officer, black, attack, military, country, gun',
#   'lda_tfidf_texts_10_doc_tokens': ['evening',
#    'struggle',
#    'civil',
#    'right',
#    'history',
#    'time',
#    'murder',
#    'white',
#    'supremacist',
#    'career',
#    'criminal',
#    'moment',
#    'modern',
#    'important',
#    'work',
#    'nation',
#    'dramatically',
#    'respect',
#    'race',
#    'relation',
#    'well',
#    'clear',
#    'evidence',
#    'age',
#    'today',
#    'society',
#    'open',
#    'hatred',
#    'contempt',
#    'fellow',
#    'man',
#    'basis',
#    'skin',
#    'color',
#    'young',
#    'people',
#    'young',
#    'hardly',
#    'childhood',
#    'parent',
#    'grandparent',
#    'million',
#    'citizen',
#    'simply',
#    'contempt',
#    'government',
#    'segregation',
#    'immutable',
#    'part',
#    'life',
#    'hardly',
#    'police',
#    'onlooker',
#    'obviously',
#    'peaceful',
#    'marcher',
#    'tear',
#    'imperfect',
#    'era',
#    'today',
#    'lawlessness',
#    'terrorism',
#    'house',
#    'lynching',
#    'routinely',
#    'black',
#    'people',
#    'merely',
#    'right',
#    'commerce',
#    'freely',
#    'evidence',
#    'nation',
#    'black',
#    'president',
#    'large',
#    'popular',
#    'vote',
#    'history',
#    'reluctantly',
#    'blind',
#    'partisanship',
#    'million',
#    'vote',
#    'people',
#    'later',
#    'astoundingly',
#    'dissimilar',
#    'republican',
#    'successor',
#    'long',
#    'area',
#    'life',
#    'position',
#    'authority',
#    'limit',
#    'race',
#    'african',
#    'major',
#    'political',
#    'party',
#    'equal',
#    'right',
#    'irrespective',
#    'race',
#    'federal',
#    'cabinet',
#    'department',
#    'executive',
#    'editor',
#    'anchor',
#    'nightly',
#    'news',
#    'black',
#    'man',
#    'racist',
#    'ideology',
#    'effectively',
#    'dare',
#    'openly',
#    'good',
#    'thing',
#    'fame',
#    'hardly',
#    'face',
#    'hate',
#    'fest',
#    'positive',
#    'development',
#    'people',
#    'shameful',
#    'friendly',
#    'meeting',
#    'vicious',
#    'racist',
#    'anti',
#    'semite',
#    'need',
#    'testament',
#    'legacy',
#    'day',
#    'news',
#    'camera',
#    'nation',
#    'violent',
#    'abuse',
#    'authority',
#    'peaceful',
#    'protester',
#    'place',
#    'vice',
#    'king',
#    'enemy',
#    'nation',
#    'legitimacy',
#    'urgency',
#    'cause',
#    'thank',
#    'ubiquitous',
#    'cellphone',
#    'camera',
#    'massive',
#    'national',
#    'awakening',
#    'place',
#    'indefensible',
#    'police',
#    'killing',
#    'black',
#    'man',
#    'aside',
#    'fringe',
#    'element',
#    'existence',
#    'police',
#    'real',
#    'problem',
#    'page',
#    'reform',
#    'issue',
#    'familiar',
#    'satisfied',
#    'long',
#    'victim',
#    'unspeakable',
#    'horror',
#    'police',
#    'brutality',
#    'well',
#    'place',
#    'race',
#    'way',
#    'bad',
#    'murder',
#    'absence',
#    'christian',
#    'voice',
#    'reason',
#    'nonviolence',
#    'acutely',
#    'radical',
#    'violent',
#    'voice',
#    'louder',
#    'hand',
#    'right',
#    'inch',
#    'creative',
#    'protest',
#    'physical',
#    'violence',
#    'famous',
#    'speech',
#    'vengeful',
#    'distrust',
#    'white',
#    'people',
#    'exchange',
#    'right',
#    'unjustly',
#    'ratification',
#    'instead',
#    'white',
#    'destiny',
#    'destiny',
#    'freedom',
#    'inextricably',
#    'freedom',
#    'life',
#    'freedom',
#    'rule',
#    'law',
#    'inextricable',
#    'bind',
#    'civil',
#    'right',
#    'person',
#    'civil_right',
#    'white_supremacist',
#    'skin_color',
#    'parent_grandparent',
#    'hate_fest',
#    'anti_semite',
#    'peaceful_protester',
#    'fringe_element',
#    'unspeakable_horror',
#    'police_brutality',
#    'destiny_destiny',
#    'civil_right']}]

# %% [markdown]
# ### 2.0 Prepare inputs for INCA

# %% [markdown]
# - Similar steps to [05-softcosine-clusters-inca.ipynb](https://github.com/wlmwng/us-right-media/blob/5156cf1590341828ca00adceeb9b8beebc612fbe/usrightmedia/code/07-newsevents/05-softcosine-clusters-inca.ipynb)

# %%
def prep(docs):
    """Prepare docs' input format for INCA.
    Renames 'doc_id' to '_id' so INCA will know which ES document to update.
    
    Args: 
        docs (list of dicts)    
    
    Returns:
        formatted docs (list of dicts)    
    """
    
    # Remove 'doc_id' so it isn't added as a redundant field on the ES document. Note this modifies the original object.
    for doc in docs:
        doc["_id"] = doc["doc_id"]
        doc.pop("doc_id")

# %%
# %%time
prep(d10)
prep(d25)
prep(d40)
# Out:
# CPU times: user 519 ms, sys: 61.2 ms, total: 580 ms
# Wall time: 578 ms

# %% [markdown]
# ### 3.0 Update Elasticsearch database through INCA

# %%
def update(docs):
    # each dict in docs will no longer have an "_id" as its popped off in INCA
    # https://github.com/wlmwng/inca/blob/1c1ed382b2db34682234af0298cf4c19ecbc7074/inca/core/database.py#L209
    myinca.database.update_documents(docs, batchsize=2000)

# %% [markdown]
# - check Kibana after running `update()` on `AmericanRenaissance_1128638341`
#
# ```
# GET /inca_alias/_search
# {"_source": {
#             "excludes": [ "META" ]
#         },
#         "query": {
#             "bool": {
#                 "filter": [
#                     {"term": {"_id": "AmericanRenaissance_1128638341"}}
#                 ]
#             }
#         }
#     }
# ```

# %%
# %%time
update(d10)
# Out:
# 100%|██████████| 364/364 [25:27<00:00,  4.20s/it]
# CPU times: user 57.6 s, sys: 960 ms, total: 58.6 s
# Wall time: 25min 35s

# %%
# %%time
update(d25)
# Out:
# 100%|██████████| 364/364 [25:25<00:00,  4.19s/it]
# CPU times: user 50.5 s, sys: 964 ms, total: 51.4 s
# Wall time: 25min 25s

# %%
# %%time
update(d40)
# Out:
# 100%|██████████| 364/364 [26:16<00:00,  4.33s/it]
# CPU times: user 50.8 s, sys: 925 ms, total: 51.7 s
# Wall time: 26min 17s

# %%
d40[11:12]
# Out:
# [{'lda_tfidf_texts_40_top_topic': 12.0,
#   'lda_tfidf_texts_40_top_topic_pct': 50.019996643066406,
#   'lda_tfidf_texts_40_topic_tokens': 'police, officer, shooting, protester, protest, city, police_officer, gun, man, suspect',
#   'lda_tfidf_texts_40_doc_tokens': ['surge',
#    'left',
#    'wing',
#    'extremist',
#    'attack',
#    'police',
#    'presence',
#    'city',
#    'emergency',
#    'service',
#    'potential',
#    'attack',
#    'announcement',
#    'left',
#    'wing',
#    'extremist',
#    'arson',
#    'attack',
#    'police',
#    'vehicle',
#    'fire',
#    'vehicle',
#    'city',
#    'police',
#    'police',
#    'directorate',
#    'result',
#    'german',
#    'tabloid',
#    'spokesman',
#    'power',
#    'distribution',
#    'box',
#    'fire',
#    'different',
#    'location',
#    'fire',
#    'radio',
#    'mast',
#    'permanent',
#    'damage',
#    'structure',
#    'viciously',
#    'home',
#    'police',
#    'special',
#    'unit',
#    'left',
#    'wing',
#    'extremism',
#    'investigation',
#    'incident',
#    'note',
#    'online',
#    'far',
#    'leftist',
#    'credit',
#    'incident',
#    'medium',
#    'away',
#    'stuff',
#    'note',
#    'shut',
#    'notorious',
#    'far',
#    'web',
#    'platform',
#    'site',
#    'linksunten',
#    'wake',
#    'massive',
#    'wave',
#    'violence',
#    'trial',
#    'connection',
#    'site',
#    'spokesman',
#    'new',
#    'measure',
#    'emergency',
#    'service',
#    'police',
#    'officer',
#    'protective',
#    'measure',
#    'able',
#    'detail',
#    'course',
#    'city',
#    'attack',
#    'extremist',
#    'arson',
#    'construction',
#    'site',
#    'euro',
#    'damage',
#    'extremist',
#    'far',
#    'home',
#    'female',
#    'real',
#    'estate',
#    'employee',
#    'construction',
#    'city',
#    'viciously',
#    'home',
#    'attack',
#    'authority',
#    'euro',
#    'bounty',
#    'extremist',
#    'arson',
#    'left_wing',
#    'left_wing',
#    'german_tabloid',
#    'left_wing',
#    'police_officer',
#    'construction_site',
#    'real_estate']}]
